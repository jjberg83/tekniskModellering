# %% [markdown]
# # Artificial Neural Network¶Regression using Artificial Neural Network

# %%
# Guide
#"""
    #Please take time to read the following guide written in red fonts. 
    #Here, you will get the brief information about the modelling
    #The ANN modelling will be performed with keras/Python built in library
    #if incase you dont have the tensor flow, you need to install by the following options
#"""

# Installing required libraries
#!pip install tensorflow
#!pip install keras

# %%
# ANN-Classification diabetes dataset. 
# """
#    As shown in the compendium, Machine Learning workflow comprises of four parts. In this example, we will follow these steps
#    
#    Step 1: Data Processing
#    
#    The quality of data should be clean and the right features should be selected to be used an input for ML
#    In xx class, we have learnt the details how to do step 1. But, in this example, we assume that the input dataset
#    pass the data-preprocessing steps and the right features are selected.
#    The data will be splitted in Training and Testing datasets. Moreover, part of the dataset also be used for validation
#    The main works here are
#        a) Importing required Python libraries 
#        b) Open file  
#        c) Separate Target Variable and Predictor Variables (Input features)
#              By convention, we use capital letter X for input features and small letter y for target variable
#        d) Visualization. We plot X and y for visualization. Or display in table form the first 5 dataset.This is not a must.
#        
#        e) Split the dataset in to Training, Testing and Validation sets. After this ANN modelling (Step 2 follows)
#
#    Step 2: Machine Learning model building and modelling
#    Once we split the dataset into traning and testing, we will create/Built ANN 
#    Part 2-1: Create Network
#        a) Initializing the ANN with tf and sequential method 
#        b) Adding the input layer and the first hidden laye
#        c) Adding the second hidden layer
#        d) Adding the output layer
#     Part 2-2 Compile and Fitting ANN to Training set
#        a) Compiling the ANN
#        b) Fitting ANN model to the Training set
#
#    Step 3: Model prediction with test data          
#        a) We will apply the ANN model and X_test to predict, y_pred
#        b) Visualization: plot y_pred vs y_test 

#    Step 4: Model accuracy analysis  
#       a) Statistica analysis to determine the model acurracy

# %%
# Installing required libraries
#!pip install tensorflow
#!pip install keras

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Part 1 - Data Preprocessing¶

# %% [markdown]
# ## Importing the dataset and visualization

# %%
#Import projectile motion dataset

#dataset = pd.read_excel('balisticwithoutwind.xlsx')

dataset = pd.read_excel('logdata.xlsx')


X = dataset.iloc[:, 0:3].values  # Select the first and the second column (0 = V0, and 1 = ang) without including the second 1
y = np.array(dataset.iloc[:, 3].values).reshape(-1,1) # Select the third column as a target (3 = R, and 2 = Time)

dataset.head()
# Out:
#          Vs     DEN     NEU        Vp
# 0  1.676857  2.3767  0.2759  3.045533
# 1  1.677172  2.2101  0.2524  2.974779
# 2  1.676252  2.1419  0.2591  2.881411
# 3  1.677030  2.1660  0.2589  2.930981
# 4  1.684534  2.1193  0.2596  2.910094

# %%
import matplotlib.pyplot as plt
plt.plot(X)
plt.show()

plt.plot(y)
plt.show()

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, shuffle=True)
 
    
# Quick sanity check with the shapes of Training and testing datasets
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

#CleanedData[TargetVariable].values
#CleanedData[TargetVariable].values
# Out:
# (777, 3)
# (777, 1)
# (334, 3)
# (334, 1)

# %% [markdown]
# # Part 2 - Building the ANN¶

# %% [markdown]
# ## Initializing the ANN¶

# %%
ann = Sequential()

# %% [markdown]
# ## Adding the input layer and the first hidden laye

# %%
ann.add(Dense(units=5, input_dim=3, kernel_initializer='normal',activation='relu'))

# %% [markdown]
# ## Adding the second hidden layer

# %%
ann.add(Dense(units=5, kernel_initializer='normal',activation='relu'))

# %% [markdown]
# ## Adding the output layer

# %%
ann.add(Dense(units=1, kernel_initializer='normal'))

# %% [markdown]
# # Part 3 - Model Compiling and Training the ANN¶

# %% [markdown]
# ## 3.1 Compiling the ANN

# %%
model = ann.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# ## 3.2 Fitting the ANN to the Training set

# %%
model = ann.fit(X_train, y_train, batch_size = 32, epochs = 500, shuffle=False)
# Out:
# Epoch 1/500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 2/500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 3/500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 4/500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 5/500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 6/500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 7/500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 8/500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 9/500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 10/500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 11/500
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 12/500
# ...

# %% [markdown]
# # Part 4 Model Prediction and comparison

# %%
# Prediction with ANN using X_test input
y_pred = ann.predict(X_test)

# Plotting Predicted vs measured (y_test)
#A) Scatter plot
plt.scatter(y_test, y_pred)

plt.title('ANN model vs Measurment')
plt.ylabel('ANN model predicted')
plt.xlabel('Measurment')
plt.show()

#A) Line plot
plt.plot(y_pred)
plt.plot(np.array(y_test).reshape(-1,1))
plt.title('ANN model vs Measurment')
plt.ylabel('ANN model predicted/Measurment')
plt.xlabel('# data number')
plt.legend(['y_pred', 'y_test'], loc='upper left')

plt.show()
# Out:
# 11/11 [==============================] - 0s 2ms/step

# %% [markdown]
# # Part 5 Model Performance Accuracy Analysis

# %%
import sklearn.metrics
mse_no=sklearn.metrics.mean_squared_error(y_test,ann.predict(X_test))
r2_no=sklearn.metrics.r2_score(y_test,ann.predict(X_test))
# Out:
# ...
# 11/11 [==============================] - 0s 2ms/step

# %%
print('Mean Square Error       :',mse_no)
print('R2 Score                :',r2_no)
# Out:
# Mean Square Error       : 0.006015121686941563
# R2 Score                : 0.9638290314313475

# %%
# list all data in history
print(model.history.keys())
plt.plot(model.history['loss'])
plt.grid()
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()
# summarize history for loss
plt.show()
# Out:
# dict_keys(['loss'])

# %%
# Using the lesson of Task 2, we will generate Linear regression between model prediction and true data

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
regr = LinearRegression()
regr.fit(np.array(y_test).reshape(-1,1),ann.predict(X_test))
y_pred = regr.predict(np.array(y_test).reshape(-1,1))

print ("coefficients : ",regr.coef_[0][0])   #Slope
print ("Intercept : ",regr.intercept_[0])    #Intercept

print('R_Squared:', r2_score(np.array(y_test).reshape(-1,1), y_pred))
# Out:
# 11/11 [==============================] - 0s 2ms/step
# coefficients :  0.9602734726722513
# Intercept :  0.15186434740953425
# R_Squared: 0.9983847384050653

# %%
# Here we will plot both the scatter and the line plots

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=380)

# Scatter plot of the true and the prediction obtained from ANN
plt.scatter(np.array(y_test).reshape(-1,1),ann.predict(X_test),color='blue')


# Line plot obtained from the true and predicted from the true using linearRegression

## Result for '' R''
plt.plot(np.array(y_test).reshape(-1,1),   regr.coef_[0][0]*y_test.reshape(-1,1)  + regr.intercept_[0], '-r')


## Result for ''Time''
#plt.plot(y_test_orig,   1.0077*y_test_orig  -0.0741, '-r')


plt.title('ANN model vs Balistic model (Test Data)')
plt.ylabel('ANN model prediction',fontsize=14)
#plt.xlabel('Measurement(Training Data)',fontsize=14)
plt.xlabel('Balistic Model (Test Data)',fontsize=14)
plt.legend(['Balistic Model data vs ANN model data', 'Linear Trendline'], loc='upper left', fontsize=12)


plt.show()
# Out:
# 11/11 [==============================] - 0s 2ms/step

# %%
y_test.shape
# Out:
# (334, 1)

# %%
y_pred.shape
#y_test
# Out:
# (334, 1)

# %%
ann.predict(X_test).shape
# Out:
# 11/11 [==============================] - 0s 2ms/step
# (334, 1)

# %%
np.array(y_test.reshape(-1,1)).shape
# Out:
# (334, 1)
